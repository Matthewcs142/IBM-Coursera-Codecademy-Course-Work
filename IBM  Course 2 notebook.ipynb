# %% [markdown]
# # H1 My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# <p>Hello everyone! My name is <strong>Matthew Seaman</strong></p><br>
# <p>Please forgive the use of raw html in the markdown in this notebook</p><br>
# <p>The markdown cheat sheet said that it mostly works and I happen to be familiar with html</p><br>
# <p>Please forgive the use of inline styling in this markdown as well</p><br>
# <p>My current career is in international foreign language teaching, but my career has be disrupted because of the pandemic.</p><br>
# <p>I hope to get change my career to programming and data science, and possibly merge that with corpus linguistics and language teaching to apply data science to language learning</p><br>

# %% [markdown]
# <p style="font-style: italic;">I am interested in data science for a number of reasons so I will only mention some of my top reasons. Due to my undergraduate studies in a variety of social sciences and my personal studies in corpus linguistics, data driven language learning, business, and education I am aware of how powerful data science can be. As an example, data science methods could be applied to the language classroom to track and analyze a large number of variables measuring not only vocabulary growth but also environmental influences on vocabulary growth, which could not only improve the efficiency of language education but also provide regularly updating information that tracks student progress towards institutional goals and demonstrate curriculum effectiveness. When combined with corpus linguistics, this could be a very powerful approach for schools, especially private schools which are subject to and concerned with a lot of the same forces and questions that any other firm is subject to and concerned with. Another reason for my interest in data science is that it is difficult to make ends meet as a foreign language instructor in countries where the primary language happens to be the language you are an instructor for.</p>

# %% [markdown]
# ### H3 My code in the next cell is a small project that I did on Codecademy's website. I took a data set containing transaction information for a craft store stored in a string and I cleaned it, separated it, and generated a small summary for the amount of each product sold by the store.

# %%
daily_sales = \
"""Edith Mcbride   ;,;$1.21   ;,;   white ;,; 
09/15/17   ,Herbert Tran   ;,;   $7.29;,; 
white&blue;,;   09/15/17 ,Paul Clarke ;,;$12.52 
;,;   white&blue ;,; 09/15/17 ,Lucille Caldwell   
;,;   $5.13   ;,; white   ;,; 09/15/17,
Eduardo George   ;,;$20.39;,; white&yellow 
;,;09/15/17   ,   Danny Mclaughlin;,;$30.82;,;   
purple ;,;09/15/17 ,Stacy Vargas;,; $1.85   ;,; 
purple&yellow ;,;09/15/17,   Shaun Brock;,; 
$17.98;,;purple&yellow ;,; 09/15/17 , 
Erick Harper ;,;$17.41;,; blue ;,; 09/15/17, 
Michelle Howell ;,;$28.59;,; blue;,;   09/15/17   , 
Carroll Boyd;,; $14.51;,;   purple&blue   ;,;   
09/15/17   , Teresa Carter   ;,; $19.64 ;,; 
white;,;09/15/17   ,   Jacob Kennedy ;,; $11.40   
;,; white&red   ;,; 09/15/17, Craig Chambers;,; 
$8.79 ;,; white&blue&red   ;,;09/15/17   , Peggy Bell;,; $8.65 ;,;blue   ;,; 09/15/17,   Kenneth Cunningham ;,;   $10.53;,;   green&blue   ;,; 
09/15/17   ,   Marvin Morgan;,;   $16.49;,; 
green&blue&red   ;,;   09/15/17 ,Marjorie Russell 
;,; $6.55 ;,;   green&blue&red;,;   09/15/17 ,
Israel Cummings;,;   $11.86   ;,;black;,;  
09/15/17,   June Doyle   ;,;   $22.29 ;,;  
black&yellow ;,;09/15/17 , Jaime Buchanan   ;,;   
$8.35;,;   white&black&yellow   ;,;   09/15/17,   
Rhonda Farmer;,;$2.91 ;,;   white&black&yellow   
;,;09/15/17, Darren Mckenzie ;,;$22.94;,;green 
;,;$19.55 ;,; green&white&red ;,;   09/15/17 ,Karl Ross;,;   $15.68;,;   white ;,;   09/15/17 , Brandy Cortez ;,;$23.57;,;   white&red   ;,;09/15/17, 
Mamie Riley   ;,;$29.32;,; purple;,;09/15/17 ,Mike Thornton   ;,; $26.44 ;,;   purple   ;,; 09/15/17, 
Jamie Vaughn   ;,; $17.24;,;green ;,; 09/15/17   , 
Noah Day ;,;   $8.49   ;,;green   ;,;09/15/17   
,Josephine Keller ;,;$13.10 ;,;green;,;   09/15/17 ,   Tracey Wolfe;,;$20.39 ;,; red   ;,; 09/15/17 ,
Ignacio Parks;,;$14.70   ;,; white&red ;,;09/15/17 
, Beatrice Newman ;,;$22.45   ;,;white&purple&red 
;,;   09/15/17, Andre Norris   ;,;   $28.46   ;,;   
red;,;   09/15/17 ,   Albert Lewis ;,; $23.89;,;   
black&red;,; 09/15/17,   Javier Bailey   ;,;   
$24.49   ;,; black&red ;,; 09/15/17   , Everett Lyons ;,;$1.81;,;   black&red ;,; 09/15/17 ,   
Abraham Maxwell;,; $6.81   ;,;green;,;   09/15/17   
,   Traci Craig ;,;$0.65;,; green&yellow;,; 
09/15/17 , Jeffrey Jenkins   ;,;$26.45;,; 
green&yellow&blue   ;,;   09/15/17,   Merle Wilson 
;,;   $7.69 ;,; purple;,; 09/15/17,Janis Franklin   
;,;$8.74   ;,; purple&black   ;,;09/15/17 ,  
Leonard Guerrero ;,;   $1.86   ;,;yellow  
;,;09/15/17,Lana Sanchez;,;$14.75   ;,; yellow;,;   
09/15/17   ,Donna Ball ;,; $28.10  ;,; 
yellow&blue;,;   09/15/17   , Terrell Barber   ;,; 
$9.91   ;,; green ;,;09/15/17   ,Jody Flores;,; 
$16.34 ;,; green ;,;   09/15/17,   Daryl Herrera 
;,;$27.57;,; white;,;   09/15/17   , Miguel Mcguire;,;$5.25;,; white&blue   ;,;   09/15/17 ,   
Rogelio Gonzalez;,; $9.51;,;   white&black&blue   
;,;   09/15/17   ,   Lora Hammond ;,;$20.56 ;,; 
green;,;   09/15/17,Owen Ward;,; $21.64   ;,;   
green&yellow;,;09/15/17,Malcolm Morales ;,;   
$24.99   ;,;   green&yellow&black;,; 09/15/17 ,   
Eric Mcdaniel ;,;$29.70;,; green ;,; 09/15/17 
,Madeline Estrada;,;   $15.52;,;green;,;   09/15/17 
, Leticia Manning;,;$15.70 ;,; green&purple;,; 
09/15/17 ,   Mario Wallace ;,; $12.36 ;,;green ;,; 
09/15/17,Lewis Glover;,;   $13.66   ;,;   
green&white;,;09/15/17,   Gail Phelps   ;,;$30.52   
;,; green&white&blue   ;,; 09/15/17 , Myrtle Morris 
;,;   $22.66   ;,; green&white&blue;,;09/15/17"""

#------------------------------------------------
# Start coding below!
#array name = daily_sales
#project assignment: clean and manipulated the data stored in the string above
daily_sales_replaced = daily_sales.replace(';,;', ';')
#print(daily_sales_replaced)

daily_transactions = daily_sales_replaced.split(',')
#print(daily_transactions)

def transactions_split (array):
  new_array = []
  for element in array:
    new_array.append(element.split(';'))
  return new_array
#print(transactions_split(daily_transactions))
daily_transactions_split = transactions_split (daily_transactions)
#print(daily_transactions_split)

#This space_cleaner function is particularly important because it illustrates how to access contents of sub arrays without destroying the sub arrays in the process. Not only do you have to nest loops in order to access sub array contents, but you also have to nest empty arrays in order to preserve the sub arrays. If you do not nest empty arrays like this, when you append the cleaned data points to the main array, you will lose all of the sub array groupings and the ability filter out specific data values in those sub arrays via iteration.
def space_cleaner (array):
  clean_elements = []
  for element in array:
    clean_items = []
    for item in element:
      clean_items.append(item.strip())
    clean_elements.append(clean_items)
  return clean_elements
transactions_clean = space_cleaner(daily_transactions_split)
#print(transactions_clean)
  
customers = []
sales = []
thread_sold = []

for element in transactions_clean:
  customers.append(element[0])
  sales.append(element[1])
  thread_sold.append(element[2])

#print(customers)
#print(sales)
#print(thread_sold)

def sales_prep_array (array):
  sales_prepped = []
  for item in array:
    sales_prepped.append(item.strip('$'))
  return sales_prepped
sales_prepped = sales_prep_array(sales)
#print(sales_prepped)

def sales_sum (array):
  total_sales = 0
  for item in array:
    x = float(item)
    total_sales = total_sales + x
  return total_sales
total_sales = sales_sum(sales_prepped)  
#print(total_sales)

#This was my first attempt to separate all of the colors and return a list of individual colors. I left this function in my code for personal use as a reference. This function did work and almost did everything I wanted it to do; however, it returned a list with colors and sublists of colors where the ampersand was used. I did not want an array with lots of nested arrays like this, so I commented out this function and tried again. The two functions that come after successfully generate the array that I was looking for: an array where each individual color is an independent string, with no sub arrays.
#def color_separator (array):
  #thread_sold_split = []
  #for color in array:
    #if '&' in color:
      #thread_sold_split.append(color.split('&'))
    #else:
      #thread_sold_split.append(color)
  #return thread_sold_split
#print(thread_sold)
#print(color_separator(thread_sold))

def color_separator (array):
  new_array = []
  for color in array:
    new_array.append(color.split('&'))
  return new_array
thread_sold_split = color_separator(thread_sold) 
#print(thread_sold_split)

def color_list (array):
  new_array = []
  for element in array:
    for item in element:
      new_array.append(item)
  return new_array
color_array = color_list(thread_sold_split)
#print(color_array)

def color_count (color):
  count = 0
  for element in color_array:
    if element == color:
      count = count + 1
  return count
#print(color_count('white'))

def unique_colors(array):
  colors = []
  for element in array:
    if element in array and not element in colors:
      colors.append(element)
  return colors
colors = unique_colors(color_array)
#print(colors)

def color_summary (array):
  print("Today Thread Shed sold: ")
  for color in array:
    count = color_count(color)
    print("   {count} spools of {color} thread.".format(count = count, color = color))
  return 'End of summary'
print(color_summary(colors))
#project completed by matthew seaman on 9/6/2020
# Out:
# Today Thread Shed sold:
#    28 spools of white thread.
#    22 spools of blue thread.
#    34 spools of yellow thread.
#    17 spools of purple thread.
#    24 spools of red thread.
#    30 spools of green thread.
#    26 spools of black thread.
# End of summary

# %% [markdown]
# <p>This cell contains the last part of the assignment</p><br>
# <p>This is an example of the horizontal rule</p><br>
#
# <p> --- </p><br>
#
# <p>This is an example of how to make a block quote</p><br>
# <p> ">This is what a block quote would look like in raw markdown" </p><br>
# <p>I did not write the block quote as it might normally be writted because I do not know if I can mix it with html without messing up the notebook.</p><br>
#
# <p>This is a unordered list</p><br>
# <ul>
#     <li>This is my unordered list</li>
#     <li>I am giving it three items</li>
#     <li>so that you can see the list</li>
# </ul>
